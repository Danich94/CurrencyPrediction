# %% [markdown]
# # Прогнозирование курса валюты с использованием предсказательных моделей класса ARIMA.

# %% [markdown]
# ## 1. Описание проекта

# %% [markdown]
# На основе котировок курса доллара по отношению к рублю попробуем построить прогноз на каждый день на месяц вперед от конца данных. Для прогнозирования курса доллара будем использовать прогнозирующую модель ARIMA из библиотеки statsmodels.

# %% [markdown]
# ### Исходные данные

# %% [markdown]
# Для построения прогнозирующей модели воспользуемся данными о валютной паре 'доллар/рубль' с сайта компании `Финам`, представляющими собой среднедневной курс доллара на бирже за период времени выбранный пользователем модели.

# %% [markdown]
# ## 2. Получение исходных данных

# %% [markdown]
# Данные о валютной паре 'доллар/рубль' будем брать с сайта [finam.ru](https://finam.ru) в виде файла в формате .csv, содержащим среднедневной курс доллара на бирже в указанный пользователем период.

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
from urllib.parse import urlencode
from configparser import ConfigParser
from scipy import stats
import itertools
import statsmodels.api as sm
import statsmodels.tsa as ts
import warnings
import matplotlib.pyplot as plt
# %pylab inline
from sklearn.metrics import mean_absolute_error
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# Пример готовой ссылки на данные по курсу доллара с сайта компании `Финам`.
#
# 'http://export.finam.ru/export9.out?market=5&em=901&code=USDRUB&apply=0&df=1&mf=0&yf=2019&from=01.01.2019&dt=13&mt=5&yt=2020&to=13.06.2020&p=8&f=USDRUB_190101_200613&e=.csv&cn=USDRUB&dtf=1&tmf=1&MSOR=1&mstime=on&mstimever=1&sep=3&sep2=2&datf=4&at=1&fsp=1'

# %% [markdown]
# Создадим класс для получения данных с сайта [finam.ru](https://finam.ru) c использованием библиотеки `urllib`.

# %%
class GetDataFromSite:
    def __init__(self, config_path = os.path.join(os.getcwd(), 'finam_config.ini')):
        self.config_path = config_path
    def create_url_for_getting_data(self):
        config = ConfigParser()
        config.read(self.config_path)
        start_date_str = config.get('finam_config', 'from')
        end_date_str = config.get('finam_config', 'to')
        market = config.get('finam_config', 'market')
        period = config.get('finam_config', 'period')
        symbol_code = config.get('finam_config', 'em')
        symbol = config.get('finam_config', 'code')
        start_date = datetime.strptime(start_date_str, "%d.%m.%Y").date()
        end_date = datetime.strptime(end_date_str, "%d.%m.%Y").date()
        finam_base_url = "http://export.finam.ru/export9.out?"
        # Формируем строку с параметрами запроса:
        params = urlencode([('market', 5), ('em', symbol_code), ('code', symbol),
                           ('df', start_date.day), ('mf', start_date.month - 1), ('yf', start_date.year),
                           ('from', start_date_str),
                           ('dt', end_date.day), ('mt', end_date.month - 1), ('yt', end_date.year),
                           ('to', end_date_str),
                           ('p', period), ('f', "table"), ('e', ".csv"), ('cn', symbol),
                           ('dtf', 1), ('tmf', 3), ('MSOR', 1), ('mstime', "on"), ('mstimever', 1),
                           ('sep', 3), ('sep2', 1), ('datf', 5), ('at', 1), ('fsp', 1)])

        data_url = finam_base_url + params
        return data_url

# %% [markdown]
# Получим готовый url c необходимыми данными.

# %%
data_class = GetDataFromSite()
url = data_class.create_url_for_getting_data()

# %% [markdown]
# ## 3. Предобработка данных.

# %% [markdown]
# Подготовим и проанализируем имеющиеся данные о курсе доллара.

# %%
currency_data = pd.read_csv(url, sep=';', usecols=['<DATE>','<CLOSE>'], index_col=['<DATE>'], parse_dates= True, dayfirst=True)
currency_data.head()
currency_data.shape
# Out:
#             <CLOSE>
# <DATE>
# 2019-01-01  69.7045
# 2019-01-02  68.9165
# 2019-01-03  68.7099
# 2019-01-04  67.5415
# 2019-01-05  67.6321
# (483, 1)

# %% [markdown]
# Заполним пропущенные значения данных о курсе валюты по тем дням, когда не было торгов на бирже. В качестве значения для заполнения выберем значение курса валюты с соседней даты.

# %%
currency_data.index.name = 'Date'
currency_data.columns = ['USD']

# %%
currency_data.index = pd.to_datetime(currency_data.index)

# %%
new_dates = pd.date_range(currency_data.index.min(), currency_data.index.max())

# %%
currency_data = currency_data.reindex(new_dates, method = 'nearest')

# %%
currency_data.head()
currency_data.shape
# Out:
#                 USD
# 2019-01-01  69.7045
# 2019-01-02  68.9165
# 2019-01-03  68.7099
# 2019-01-04  67.5415
# 2019-01-05  67.6321
# (529, 1)

# %% [markdown]
# ## 4. Построение модели ARIMA.

# %% [markdown]
# #### Произведем визуальный анализ ряда.

# %%
plt.figure(figsize(16,8))
plt.plot(currency_data)
plt.title("USD exchange rate")
# Out:
# Text(0.5, 1.0, 'USD exchange rate')

# %% [markdown]
# #### Посмотрим на автокорреляционную и частичную автокорреляционную функцию исходного ряда.

# %%
_ = plt.figure(figsize=(18,10))
ax_1 = plt.subplot(2,1,1)
_ = sm.graphics.tsa.plot_acf(currency_data.USD.values.squeeze(), lags=50, ax=ax_1)
ax_2 = plt.subplot(2,1,2)
_ = sm.graphics.tsa.plot_pacf(currency_data.USD.values.squeeze(), lags=50, ax=ax_2)

# %% [markdown]
# По графику автокорреляционной функции видно, что данные о курсе валюты имеют тренд.

# %% [markdown]
# #### Проверим стационарность ряда и осуществим STL-декомпозиция ряда:

# %%
_ = plt.figure(figsize(18,10))
_ = sm.tsa.seasonal_decompose(currency_data.USD).plot()
print("Критерий Дики-Фулера p=%f" % sm.tsa.stattools.adfuller(currency_data.USD)[1])
# Out:
# Критерий Дики-Фулера p=0.235621

# %% [markdown]
# Из визуального анализа ряда видно, что ряд имеет тренд, сезонность. Критерий Дики-Фулера не отвергает нулевую гипотезу о нестационарности ряда.
# Самая главная особенность имеющегося ряда заключается в том, что он имеет увеличивающуюся во времени дисперсию (гетероскедатичность). Ряды с такими свойствами дисперсии могут быть описаны классом моделей ARCH (AutoRegressive Conditional Heteroscedasticity), но попробуем предсказать значение ряда с использованием прогнозирующих моделей класса ARIMA.

# %% [markdown]
# #### Выбор порядка дифференцирования

# %% [markdown]
# Критерий Дики-Фуллера не отвергает гипотезу нестационарности.  Для преобзования ряда к стационарному попробуем обычное дифференцирование. Затем сделаем на продифференцированном ряде STL-декомпозицию и проверим стационарность.

# %%
difference_row = currency_data.USD.diff(periods=1).dropna()
_ = plt.figure(figsize(15,10))
_ = sm.tsa.seasonal_decompose(difference_row).plot()
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(difference_row)[1])
# Out:
# Критерий Дики-Фуллера: p=0.000018

# %% [markdown]
# Критерий Дики Фулера уверенно отвергает нулевую гипотезу о нестационарности ряда.

# %% [markdown]
# #### Выбор начальных приближений для p,q,P,Q

# %% [markdown]
# Посмотрим на автокорреляционную и частичную автокорреляционную функцию продифференцированного ряда.

# %%
_ = plt.figure(figsize(18,10))
ax_1 = plt.subplot(2,1,1)
_ = sm.graphics.tsa.plot_acf(difference_row.values.squeeze(), lags=50, ax=ax_1)
ax_2 = plt.subplot(2,1,2)
_ = sm.graphics.tsa.plot_pacf(difference_row.values.squeeze(), lags=50, ax=ax_2)

# %% [markdown]
# Выбор начальных приближений для построения модели.
# Начальные приближения: q = 11, p =11, посмотрим какая модель имеет меньшее значение критерия Акаике.

# %%
d = 1
ps = list(range(12))
qs = list(range(12))

# %%
parameters_list = list(itertools.product(ps, qs))

# %% [markdown]
# #### Обучим на всех данных, сравним модели-кандидаты и  выберем  лучшую.

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(currency_data, order=(param[0], d, param[1]), seasonal_order=(0, 0, 0, 0)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong paramaters for model:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# Wall time: 15min 11s

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True))
# Out:
#     parameters         aic
# 141    (11, 9)  836.339410
# 107    (8, 11)  836.911940
# 142   (11, 10)  837.644951
# 140    (11, 8)  838.583073
# 119    (9, 11)  839.088454
# ..         ...         ...
# 37      (3, 1)  912.284937
# 17      (1, 5)  913.154375
# 61      (5, 1)  913.777720
# 49      (4, 1)  913.799070
# 0       (0, 0)  915.380442
#
# [144 rows x 2 columns]

# %% [markdown]
# Выводим информацию о лучшей предсказательной модели ARIMA

# %%
print(best_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    USD   No. Observations:                  529
# Model:              SARIMAX(11, 1, 9)   Log Likelihood                -397.170
# Date:                Sun, 14 Jun 2020   AIC                            836.339
# Time:                        10:48:06   BIC                            925.990
# Sample:                    01-01-2019   HQIC                           871.436
#                          - 06-12-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0591      0.179      0.330      0.742      -0.292       0.410
# ar.L2         -0.0346      0.156     -0.222      0.825      -0.341       0.271
# ar.L3          0.0518      0.097      0.533      0.594      -0.139       0.242
# ar.L4         -0.0738      0.080     -0.919      0.358      -0.231       0.084
# ar.L5          0.0511      0.058      0.874      0.382      -0.063       0.166
# ar.L6          0.0060      0.071      0.085      0.933      -0.134       0.146
# ar.L7          0.2792      0.066      4.251      0.000       0.150       0.408
# ar.L8         -0.3859      0.097     -3.984      0.000      -0.576      -0.196
# ar.L9         -0.2202      0.131     -1.681      0.093      -0.477       0.037
# ar.L10         0.0503      0.063      0.795      0.426      -0.074       0.174
# ar.L11         0.2558      0.045      5.744      0.000       0.169       0.343
# ma.L1         -0.1752      0.177     -0.989      0.323      -0.523       0.172
# ma.L2          0.1376      0.169      0.815      0.415      -0.193       0.469
# ma.L3         -0.0451      0.115     -0.393      0.694      -0.270       0.180
# ma.L4          0.0507      0.093      0.547      0.584      -0.131       0.232
# ma.L5         -0.1436      0.078     -1.850      0.064      -0.296       0.009
# ma.L6          0.1380      0.091      1.523      0.128      -0.040       0.316
# ma.L7         -0.3036      0.081     -3.729      0.000      -0.463      -0.144
# ma.L8          0.3294      0.118      2.798      0.005       0.099       0.560
# ma.L9          0.4427      0.129      3.432      0.001       0.190       0.696
# sigma2         0.2631      0.010     26.858      0.000       0.244       0.282
# ===================================================================================
# Ljung-Box (Q):                       35.27   Jarque-Bera (JB):              3640.86
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.96   Skew:                             1.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Выберем модель ARIMA с параметрами p=11, q=9.

# %%
selected_model = sm.tsa.statespace.SARIMAX(currency_data, order=(11, d, 9), seasonal_order=(0, 0, 0, 0)).fit(disp=-1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# #### Анализ остатков построенной модели

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
selected_model.resid.plot()
plt.ylabel(u'Residuals')

ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(selected_model.resid.values.squeeze(), lags=50, ax=ax)

print("Критерий Стьюдента: p=%f" % stats.ttest_1samp(selected_model.resid, 0)[1])
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(selected_model.resid)[1])
# Out:
# Text(0, 0.5, 'Residuals')
# Критерий Стьюдента: p=0.320154
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Остатки несмещены (подтверждается критерием Стьюдента) стационарны (подтверждается критерием Дики-Фуллера и визуально), неавтокоррелированы (подтверждается критерием Льюнга-Бокса и коррелограммой).

# %% [markdown]
# Сделаем прогноз по построенной модели.

# %% [markdown]
# ## 5. Предсказание с использованием построенной модели.

# %% [markdown]
# Для начала определим метрику качества модели.
# Mean Absolute Percentage Error - метрика качества аналогичная MAE(Mean Absolute Error), но измеряющая значения в процентах. Данную метрику удобно использовать для объяснения заказчику качества прогноза, изменяется в диапазоне $[0, +\infty)$
#
# $MAPE = \frac{100}{n}\sum\limits_{i=1}^{n} \frac{|y_i - \hat{y}_i|}{y_i}$

# %% [markdown]
# Определим функцию для подсчета метрики MAPE.

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# Определим функцию для построения прогноза модели и отрисовки графика с построенными значениями.

# %%
def plotARIMA(series, model, n_steps, d=1, plot_intervals=True, alpha=0.2):
    """
        Plots model vs predicted values
        
        series - dataset with timeseries
        model - fitted ARIMA model
        n_steps - number of steps to predict in the future
        
    """
    # adding model values
    data = series.copy()
    data.columns = ['actual']
    data['arima_model'] = model.fittedvalues
    # making a shift on d steps, because these values were unobserved by the model
    # due to the differentiating
    data['arima_model'][:d] = np.NaN
    
    # forecasting on n_steps forward 
    forecast = model.get_forecast(steps=n_steps)
    model_predictions = data.arima_model.append(forecast.predicted_mean)
    # calculate error, again having shifted on d steps from the beginning
    error = mean_absolute_percentage_error(data['actual'][d:], data['arima_model'][d:])
    

    plt.figure(figsize=(15, 7))
    plt.title("Mean Absolute Percentage Error: {0:.2f}%".format(error))    
    
    plt.plot(model_predictions, color='r', label="model")
    plt.plot(data.actual, label="actual")
    
    if plot_intervals:
        intervals = forecast.conf_int(alpha=alpha)
        intervals.columns=['lower', 'upper']
        plt.plot(intervals['lower'], "r--", alpha=0.5, label = "Up/Low confidence")
        plt.plot(intervals['upper'], "r--", alpha=0.5)
        plt.fill_between(x=intervals.index, y1=intervals['upper'], 
                         y2=intervals['lower'], alpha=0.2, color = "grey")    
    
    
    plt.legend()
    plt.grid(True);

# %%
plotARIMA(currency_data, selected_model, 30, alpha=0.5)

# %% [markdown]
# Из результирующего графика прогноза видно, что модель класса ARIMA(11,1,9) сумела сделать нетривиальный прогноз по курсу доллара со средней абсолютной ошибкой в 0.5%. Конечно же модель не берет в расчет экономические события, которые влияют на динамику курса. К тому же при увеличении горизонта прогнозирования предсказанные значения ряда становятся больше похожими на шум, колеблющийся вокруг спрогнозированной линии тренда.
